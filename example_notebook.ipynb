# %%
import data_tools
import features
import os
from matplotlib import pyplot as plt
import pandas as pd

# %%
work_dir = os.path.abspath('.')
if not os.path.isdir('sample_test'): #takes about 10-15 minutes to run
    network_path = work_dir + '/dsb2018_topcoders' # where is the network located
    full_image_name = work_dir + '/test_img.jpg' # where to take image
    sample_path = work_dir + '/sample_test' # where to put results and image tiles

    data_tools.perform_segmentation(full_image_name, sample_path, network_path, force=True)

# %%
segmentation_mask = data_tools.restore_image(work_dir + '/sample_test_segmented/color_test_sub2/')
plt.figure(figsize=(10, 8))
plt.imshow(segmentation_mask)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-41db272baaf8> in <module>
# ----> 1 segmentation_mask = data_tools.restore_image(work_dir + '/sample_test_segmented/color_test_sub2/')
#       2 plt.figure(figsize=(10, 8))
#       3 plt.imshow(segmentation_mask)
#
# ~/Dropbox/Python/embl/Sanger/segmentation/data_tools.py in restore_image(work_dir, tiff)
#     124     work_dir = Path(work_dir)
#     125
# --> 126     file_names = sorted(os.listdir(work_dir), key=lambda x: get_x_and_y(x)[::-1])
#     127     coords = np.array([get_x_and_y(n) for n in file_names])
#     128     x_max, y_max = coords.max(axis=0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yubi/Dropbox/Python/embl/Sanger/segmentation/sample_test_segmented/color_test_sub2'

# %%
df = features.NucleiFeatures(work_dir + '/sample_test_segmented/lgbm_test_sub2', work_dir + '/sample_test', features=['position', 'size']).df()

# %%
initial_image = plt.imread('test_img.jpg')

plt.figure(figsize=(14, 10))
plt.imshow(initial_image)
plt.scatter(df.x, df.y, s=0.4, color='blue')
plt.axis('off')
plt.show()
